# %%
def targ_fist_index(arr, taget):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

# %%
def lastIndex(arr):
    a = -1
    for i, x in enumerate(arr):
        if x == target:
            a = i
    return 

def bool_index(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return True
    return False

def count_occur(arr, target):
    count = 0
    for i in range(len(arr)):
        if arr[i] == target:
            count += 1
    return count

def Index_all_occur(arr, target):
    index_t = []
    for i in range(len(arr)):
        if arr[i] == target:
            index_t.append(i)
    return index_t
