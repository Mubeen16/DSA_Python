# %% [raw]
# store and  retrirve data quicky using keys
# core ideas convert a key into an index via hash function.
# best use case are in dictiioneries, caching, indexing, verification, load balancing
# famous algorithams rabin karp, dict pythons,

# %%
d = {
    1: "Geeks",
    2: "For",
    3: "Geeks"
    
    }

# %%
d2 = dict(name='mubeen', age=26)

# %%
d2
# Out:
# {'name': 'mubeen', 'age': 26}

# %%
d = {1: 'Geeks', 2: 'For', 'age': 22}

for k in d:
    print(k)
# Out:
# 1
# 2
# age

# %%
for v in d.values():
    print(v)
# Out:
# Geeks
# For
# 22

# %%
for k, v in d.items():
    print(f"{k}:{v}")
# Out:
# 1:Geeks
# 2:For
# age:22

# %%
class SimpleHastable:
    def __init__(self, size):
        self.size =size
        self.table = [None]*size
    def hasfunc(self, key):
        total = 0
        for i, char in enumerate(key):
            total += (i + 1) * ord(char)
        return total % self.size
    def insert(self, key, value):
        index = self.hash_func(key)
        self.table[index] =  value
    def get(self, key):
# Out:
#   Cell In[20], line 13
#     def get(self, key):
#                        ^
# SyntaxError: incomplete input

# %%
class SimpleHashTable:
    def __init__(self, size):
        self.size = size
        self.table = [None] * size

    def hash_func(self, key):
        total = 0
        for i, char in enumerate(key):
            total += (i + 1) * ord(char)
        return total % self.size

    def insert(self, key, value):
        index = self.hash_func(key)
        self.table[index] = value

    def get(self, key):
        index = self.hash_func(key)
        return self.table[index]

# Example
ht = SimpleHashTable(10)
ht.insert("mubeen", 22)
ht.insert("data", 30)

print(ht.table)
print(ht.get("mubeen"))
# Out:
# [30, None, None, None, None, None, 22, None, None, None]
# 22

# %%
class hasttable:
    def __init__(self, size):
        self.size = size
        self.table = [None]*size
    def hashfunc(self, key):
        total = 0
        for i, char in enumerate(key):
            total += (i + 1)*ord(char)
        return total % self.size

    def insert(self, key, value):
        index = self.hash_func(key)
        self.table[index] = value

# %%
print("hellow Mubeen")
# Out:
# hellow Mubeen
