# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.prev = None
        self.next = None

if __name__ == "__main__":
    # Create the first node (head of the list)
    head = Node(10)

    # Create and link the second node
    head.next = Node(20)
    head.next.prev = head

    # Create and link the third node
    head.next.next = Node(30)
    head.next.next.prev = head.next

    # Create and link the fourth node
    head.next.next.next = Node(40)
    head.next.next.next.prev = head.next.next

    # Traverse the list forward and print elements
    temp = head
    while temp is not None:
        print(temp.data, end="")
        if temp.next is not None:
            print(" <-> ", end="")
        temp = temp.next
# Out:
# 10 <-> 20 <-> 30 <-> 40

# %%
class Node:
    def __init__(self, val):
        self.data = val
        self.prev = None
        self.next = None

def forward_tra(head):
    curr = head
    while curr is not None:
        print(curr.data)
        curr = curr.next
    print()

def backward(tail):
    curr = tail
    while curr is not None:
        print(curr.data)
        curr = curr.prev

head = Node(1)
second = Node(2)
third = Node(3)

head.next = second
second.prev = head
second.next = third
third.prev = second

# %%
class Node:
    def __init__(self, new_data):
        self.data = new_data
        self.next = None
def travesal(head):
    while head is not None:
        print(head.data, end=" > ")
        head = head.next
    print()

# %%
head  = Node(10)
head.next = Node(20)
head.next.next = Node(30)
head.next.next.next = Node(40)
travesal(head)
# Out:
# 10 > 20 > 30 > 40 >

# %%
def __init__(self, data):
    self.data = data
    self.next = None

def travesersal_recu(thala):
    if thala is None:
        print()
        return
    print(thala.data, end=' --> ')
    travesersal_recu(thala.next)

# %%
head  = Node(10)
head.next = Node(20)
head.next.next = Node(30)
head.next.next.next = Node(40)
travesersal_recu(head)
# Out:
# 10 --> 20 --> 30 --> 40 -->

# %%
def insert_atFront(head, x):
    new_node = Node(x)
    newNode.next = head
    return newNode

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# existing linked list
head = Node(2)
head.next = Node(3)
head.next.next = Node(4)
new_node = Node(1)
new_node.next = head
head = new_node

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

head = Node(10)
head.next = Node(20)
head.next.next = Node(30)

newNode = Node(40)

if head is None:
    head = newNode
else:
    temp = head
    while temp.next is not None:
        temp = temp.next
    temp.next = newNode

# %%
temp = head
while temp:
    print(temp.data, end="-->")
    temp = temp.next
print("None")
# Out:
# 10-->20-->30-->40-->None

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# existing linked list
head = Node(10)
head.next = Node(20)
head.next.next = Node(30)

# insert new node with value 40 at end
newNode = Node(40)

# if list is empty
if head is None:
    head = newNode
else:
    temp = head
    while temp.next is not None:
        temp = temp.next
    temp.next = newNode

# %%
temp = head
while temp:
    print(temp.data, end=" -> ")
    temp = temp.next
print("None")
# Out:
# 10 -> 20 -> 30 -> 40 -> None

# %%
class Node:
    def __init__(self, data):
        self.val = data
        self.next = None

head = Node(1)
head.next = Node(2)
head.next.next = Node(4)

pos =3
val = 3

newNode = Node(val)


temp =  head
for i in range(1, pos-1):
    if temp is None:
        break
    temp = temp.next
    if temp:
        newNode.next = temp.next
        temp.next = newNode

# %%
class Node:
    def __init__(self, x):
        self.val = x
        self.next = None

# Create the linked list: 1 -> 2 -> 4
head = Node(1)
head.next = Node(2)
head.next.next = Node(4)

val = 3
pos = 3

curr = head
for i in range(1, pos-1):
    
    curr = curr.next # there actually understood here becous now this wiil be pos - 1
if curr is not None:  # why this again not necesssary
    newNode = Node(val) # making node as val (3)
    newNode.next = curr.next # pointing newnode but curr = curr.next?rhis will be same
    curr.next = newNode #again not make any sense

# %%
for i in range(pos-1):
    head = head.next
    newnode = Node(val) # why do we need nname as new node, is achiecvabel without it
    newnode.next = head.next
    head.next = newnode
