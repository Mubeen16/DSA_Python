# %%
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None

def deleteHead(head):
    temp = head.next
    head = None
    return head

# %%
def remove_lastNode(head):
    if head is None:
        return None
    if head.next is None:
        return None
    secondlast = head
    while secondlast is not None:
        secondlast = secondlast.next
    secondlast.next = None
    return head

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

def deleteNode(head, position):
    temp = head
    if position ==1:
        head = temp.next
        return head
    prev = None
    for i in range(1, position):
        prev = temp
        temp = temp.next
    prev.next = temp.next
    return head
def printList(head):
    while head is not None:
        print(f"{head.data} -> ", end="")
        head = head.next
    print("nullptr")

head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)


position = 3
head = deleteNode(head, position)
