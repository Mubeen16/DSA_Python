# %%
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None

def insert_at_end(head, x):
    newNode = Node(x)
    if head is None:
        return newNode

    Last = head
    while Last.next is not None:
        last = last.next
    last.next = newNode
    return head

# %%
class Node:
    def __init__(self, x):
        self.data = x
        self.next = None
def insert_at_end(head, x):
    newNode = Node(x)

    if head is None:
        return newNode
    last = head
    while last.next is not None:
        last = last.next
    last.next = newNode
    return head

# %%
class Node:
    def __init__(self, x):
        self.val = x
        self.next = None

def insertPos(head, pos, val):
    if pos < 1:
        return head

    if pos == 1:
        newNode = Node(val)
        newNode.next = head 
        return newNode

    if pos == 1:
        newNode = Node(val)
        newNode.next = head
        return newNode

    curr = head
