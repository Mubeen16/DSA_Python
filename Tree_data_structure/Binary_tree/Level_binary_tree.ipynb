# %%
q = [(root, 1)] #ques that store node, and level
levels = 0 #varible to track the maximum level seen

while q: 
    node, level = q.pop(0)
    levels = max(levels, level)

    if node.left:
        q.append((node.left, level + 1))
    if node.right:
        q.append((node.right, level + 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 q = [(root, 1)] #ques that store node, and level
#       2 levels = 0 #varible to track the maximum level seen
#       4 while q:
#
# NameError: name 'root' is not defined
